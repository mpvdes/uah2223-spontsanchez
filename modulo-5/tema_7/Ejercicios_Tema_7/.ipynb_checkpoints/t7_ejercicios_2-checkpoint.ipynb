# %% [markdown]
# # Ejercicios
#
#
# En este ejercicio vamos procesar datos extraidos de Twitter a través de su API.
# El fichero se llama [tweets.xlsx](tweets.xlsx)

# %% [markdown]
# Se pide:

# %% [markdown]
# __EJ 1.__ Importa la librería pandas.
# Crea un dataframe llamado `tweets` con los datos del fichero `tweets.xlsx`.

# %%
import pandas as pd
tweets = pd.read_excel('tweets.xlsx')
tweets
# Out:
#                      id                                              texto  \
# 0   1500987576328637952  Con @razón @abc dicen “Ojo con el 2022”.\nSi e...
# 1   1501094609870594048  Buenos días desde Kiev.\n\nHoy es 8 de marzo, ...
# 2   1500572181906006016  Si Antioquia cambia, Colombia cambia.\n\nMi me...
# 3   1500568092576988928  Este domingo en @fincamarta se vivió una exper...
# 4   1500677645876580096  Villas de Salvárcar\n2010\nEn Cd Juárez, por u...
# 5   1500811659018972928  Ataque en discoteca @rr @locura\n\nLa joven Na...
# 6   1500628164086832896  Mis felicitaciones a @BlandonJose y los miembr...
# 7   1500889162311998976  Con @jlespert en la Comisión de Presupuesto, e...
# 8   1500482574480657920  Violación de una joven en una fiesta durante e...
# 9   1500859981410681088  Esto es lo que tenemos que promover como parte...
# 10  1500598219029499904  ¡La fiesta de la mayor afición del muuuuundooo...
# 11  1501060397364915968  Hoy celebramos a San Juan de Dios, patrono de ...
# 12  1500900738133810944  Fiesta VIP en Olivos: el juez ordenó conocer e...
# 13  1500906806062850048  ¡DE ANIVERSARIO!  🥳\n\n@TigresOficial está de ...
# 14  1500561774935952896  Ritmu! Ritmu!!!🤠🐎🌵El maltés Aidan será el alma...
# 15  1500644305207057920  En la recta final de nuestro Carnaval quiero d...
# 16  1500845714691304960  🗳️Estaremos en Colombia🇨🇴 para monitorear las ...
# 17  1500705567622450944  Comenzamos la novena al Santo Cura Brochero de...
# 18  1500599461000663040  Cuando la fiesta es en tu casa y ya te quieres...
# 19  1500531696550265088  🤝 Vivamos este partido como una fiesta. #Fútbo...
# 20  1500645783045124096  Que el fútbol siempre sea una fiesta. 🥁🎺🏳🏁 #Fú...
# 21  1500580736381989120  “Que no le falte pueblo a nuestro presidente. ...
# 22  1500505467394703104  #Queretaro La violencia nunca es el camino. El...
# 23  1500512533727236096  Tremendo acto con caravana del NO!\nUn fiesta ...
# 24  1500494394838896896  Esto fue sólo parte de la fiesta. La caballada...
# 25  1500490740962676992  El futbol TIENE/DEBE ser una fiesta familiar d...
# 26  1500463709340188928  #Cuba🇨🇺 felicita al pueblo y gobierno de la Re...
# 27  1498679140375052032  El presidente @alferdez está dando un discurso...
# 28  1499095986219725056  "Después de ganar el US Open, no tenía dónde f...
# 29  1500352325294113024  Un estadio de fútbol es para muchos un santuar...
# 30  1500477570206339072  Hombre muere tras ser baleado en su cabeza: ha...
# 31  1500440116107620096  La argolla del poder en Napo también organizó ...
# 32  1499211483644932096  CONFIRMADO: UNO SE MUEVE AL RITMO DE LA HINCHA...
# 33  1500494486039843072  Extraordinaria Fiesta de la #Vendimia2022 🍇🇦🇷....
# 34  1500491104751428096  Miren lo que fue parte de la fiesta de Uruguay...
# 35  1500483116187721984  🥳 Y comenzamos el domingo con alegría, abrazos...
# 36  1498724465693232896  ¡Llegó el mejor mes con las promos más reVelde...
# 37  1500444583389498880  🥳🎶 #CamilaCabello celebró su cumpleaños a lo g...
# 38  1498836002579833088  Dice el de Petroperú que Jamas ha visto a Kare...
# 39  1499870150912352000  En Bogotá estamos de fiesta!! Es el momento de...
# 40  1499912268057873920  Lleno total en Bogotá. ⭐⭐⭐⭐⭐⭐⭐\n\n@pactocol \n...
# 41  1498443507345678080  ¡LA FIESTA QUE HACEMOS SIEMPRE! https://t.co/G...
# 42  1498352296782089984  ¡La vida es una fiesta! 🎉 busca tu mejor disfr...
# 43  1498286819171054080  Polémica: Mauricio Isla se perdió partido de F...
# 44  1498350398947696896  Carlos Antonio Linares es un degenerado sexual...
# 45  1498327897924256000  Este fin de semana, acompañamos al Carnaval de...
# 46  1498382462854042112  🥁🎉¡Hoy llegan los Carnavales a Almirante Brown...
# 47  1498349212177767936  TODOS JUNTOS SOMOS PARTE DE ESTA FIESTA, SE VI...
# 48  1498437651749342976  ¡Ya está Trueno en el Carnaval de Pilar! ⚡🤟🏻\n...
# 49  1498362701252334080  Se viene el #Belgrano360 un recibimiento histó...
# 50  1498277238898363904  🤍💙 ¡Todos a Butarque y que ningún abonado se q...
# 51  1498303588094853120  Hoy en Sevilla. Hemos venido los de @vox_malag...
# 52  1498273451022429952  La Fiesta del Cambio #ComienzaElCambio #ElPact...
#
#               autor      fecha  #retweets
# 0    GustavoBolivar 2022-03-08     1947.0
# 1         pmarsupia 2022-03-08      969.0
# 2     piedadcordoba 2022-03-06      400.0
# 3        DiazCanelB 2022-03-06        NaN
# 4   epigmenioibarra 2022-03-07      191.0
# 5        ABCDigital 2022-03-07       76.0
# 6        romuloroux 2022-03-07       65.0
# 7    CarolinaPiparo 2022-03-07        NaN
# 8        mauroszeta 2022-03-06     1348.0
# 9   daniel_velasco5 2022-03-07       47.0
# 10      Flamengo_es 2022-03-06      116.0
# 11        aciprensa 2022-03-08        NaN
# 12     todonoticias 2022-03-07       50.0
# 13    record_mexico 2022-03-07       46.0
# 14     eurospaincom 2022-03-06       45.0
# 15    CosseCarolina 2022-03-07        NaN
# 16   uniglobalunion 2022-03-07        NaN
# 17        aciprensa 2022-03-07       28.0
# 18   MarioAguilarMG 2022-03-06       48.0
# 19     AlianzaFC_sv 2022-03-06       91.0
# 20     AlianzaFC_sv 2022-03-07       19.0
# 21          proceso 2022-03-06       17.0
# 22      EVerastegui 2022-03-06      105.0
# 23   Dip_ConradoRod 2022-03-06       49.0
# 24         casiain1 2022-03-06        NaN
# 25           lajosa 2022-03-06      140.0
# 26       CubaMINREX 2022-03-06       91.0
# 27       WolffWaldo 2022-03-01     2691.0
# 28     VarskySports 2022-03-02      861.0
# 29      pavelpardo8 2022-03-06      386.0
# 30           biobio 2022-03-06       41.0
# 31   VillaFernando_ 2022-03-06      150.0
# 32          SC_ESPN 2022-03-03      647.0
# 33        GugaLusto 2022-03-06       33.0
# 34         casiain1 2022-03-06        NaN
# 35       DvoTachira 2022-03-06       34.0
# 36     viajaVolaris 2022-03-01      273.0
# 37    FMvidaRosario 2022-03-06       46.0
# 38      esquinabaja 2022-03-02      309.0
# 39      DavidRacero 2022-03-04      336.0
# 40   PizarroMariaJo 2022-03-05      288.0
# 41          Newells 2022-02-28      380.0
# 42        VTVcanal8 2022-02-28      195.0
# 43      Cooperativa 2022-02-28      106.0
# 44            PNCSV 2022-02-28      103.0
# 45  AlvaroDelgadoUy 2022-02-28       35.0
# 46    CascallaresPJ 2022-02-28       42.0
# 47          _LBDTW_ 2022-02-28       42.0
# 48  FedericoAchaval 2022-02-28       23.0
# 49          _LBDTW_ 2022-02-28       34.0
# 50        CDLeganes 2022-02-28       18.0
# 51  rubenmansolivar 2022-02-28       26.0
# 52      RoyBarreras 2022-02-28       29.0

# %% [markdown]
# __EJ 2.__ Escribe la instrucción que muestra los nombres de las columnas.

# %% [markdown]
# __EJ 3.__ Elimina la primera columna

# %%
# Sol:

# %% [markdown]
# __EJ 4.__ Estudia los valores NaN que hay en la tabla

# %%
# Sol:

# %% [markdown]
# __EJ 5.__ Ejecuta la función `info()` para obtener más información de las columnas

# %%
# Sol:

# %% [markdown]
# __EJ 6.__ Usa la función `dropna` para eliminar los tweets que contienen `NAN`  en el campo `#retweets`.

# %%
# Sol:

# %% [markdown]
# __EJ 7.__ Ordena los datos de forma creciente de fecha

# %%
# Sol:

# %% [markdown]
# __EJ 8.__ Crea una columna nueva con la información del tamaño del texto del tweet. Puedes usar funciones `lambda` aplicadas con `map`.

# %%
# Sol:

# %% [markdown]
# __EJ 8.__ Crea una columna nueva con la información del número de palabras del texto del tweet. Puedes usar funciones `lambda` aplicadas con `map`.

# %%
# sol:

# %% [markdown]
# __EJ 9.__ Selecciona los tweets cuyo autor es `AlianzaFC_sv`.

# %%
# sol:

# %% [markdown]
# __EJ 10.__ Selecciona los tweets cuyo tamaño es superior a 100 caracteres.

# %%
# sol:

# %% [markdown]
# __EJ 11.__ Añadir una columna con las menciones a otras cuentas. La idea es extraer partes del texto y mostrarlo como una columna nueva usando expresiones regulares junto con la función `findall`.
#
# Ejemplos:

# %%
# Extraer una palabra concreta, por ejemplo 'Colombia'

resultado = tweets['texto'].str.findall(r'(Colombia)', flags = re.IGNORECASE)

# %%
# Extraer números
er = r'([0-9]+)'

resultado = tweets['texto'].str.findall(er, flags = re.IGNORECASE)

# %%
# Extraer urls del texto
er = r'(http+[\S]*)'

resultado = tweets['texto'].str.findall(er, flags = re.IGNORECASE)

# %% [markdown]
# `\w` significa cualquier carácter alfanumético
#
# `\W` significa cualquier carácter
#
# `* ` significa 0 o más repeticiones
#
# `+ ` significa 1 o más repeticiones

# %%
# sol:
import re
tweets["menciones"] = tweets['texto'].str.findall(r'([@][\w]*)', flags = re.IGNORECASE)
tweets
# Out:
#     Unnamed: 0                   id  \
# 0            0  1500987576328637952
# 1            1  1501094609870594048
# 2            2  1500572181906006016
# 3            3  1500568092576988928
# 4            4  1500677645876580096
# 5            5  1500811659018972928
# 6            6  1500628164086832896
# 7            7  1500889162311998976
# 8            8  1500482574480657920
# 9            9  1500859981410681088
# 10          10  1500598219029499904
# 11          11  1501060397364915968
# 12          12  1500900738133810944
# 13          13  1500906806062850048
# 14          25  1500561774935952896
# 15          26  1500644305207057920
# 16          27  1500845714691304960
# 17          28  1500705567622450944
# 18          38  1500599461000663040
# 19          39  1500531696550265088
# 20          40  1500645783045124096
# 21          41  1500580736381989120
# 22          42  1500505467394703104
# 23          43  1500512533727236096
# 24          47  1500494394838896896
# 25          48  1500490740962676992
# 26          49  1500463709340188928
# 27          50  1498679140375052032
# 28          51  1499095986219725056
# 29          52  1500352325294113024
# 30          53  1500477570206339072
# 31          54  1500440116107620096
# 32          55  1499211483644932096
# 33          56  1500494486039843072
# 34          57  1500491104751428096
# 35          58  1500483116187721984
# 36          68  1498724465693232896
# 37          69  1500444583389498880
# 38          70  1498836002579833088
# 39          71  1499870150912352000
# 40          72  1499912268057873920
# 41          73  1498443507345678080
# 42          75  1498352296782089984
# 43          76  1498286819171054080
# 44          77  1498350398947696896
# 45          78  1498327897924256000
# 46          79  1498382462854042112
# 47          80  1498349212177767936
# 48          81  1498437651749342976
# 49          82  1498362701252334080
# 50          83  1498277238898363904
# 51          84  1498303588094853120
# 52          85  1498273451022429952
#
#                                                 texto            autor  \
# 0   Con @razón @abc dicen “Ojo con el 2022”.\nSi e...   GustavoBolivar
# 1   Buenos días desde Kiev.\n\nHoy es 8 de marzo, ...        pmarsupia
# 2   Si Antioquia cambia, Colombia cambia.\n\nMi me...    piedadcordoba
# 3   Este domingo en @fincamarta se vivió una exper...       DiazCanelB
# 4   Villas de Salvárcar\n2010\nEn Cd Juárez, por u...  epigmenioibarra
# 5   Ataque en discoteca @rr @locura\n\nLa joven Na...       ABCDigital
# 6   Mis felicitaciones a @BlandonJose y los miembr...       romuloroux
# 7   Con @jlespert en la Comisión de Presupuesto, e...   CarolinaPiparo
# 8   Violación de una joven en una fiesta durante e...       mauroszeta
# 9   Esto es lo que tenemos que promover como parte...  daniel_velasco5
# 10  ¡La fiesta de la mayor afición del muuuuundooo...      Flamengo_es
# 11  Hoy celebramos a San Juan de Dios, patrono de ...        aciprensa
# 12  Fiesta VIP en Olivos: el juez ordenó conocer e...     todonoticias
# 13  ¡DE ANIVERSARIO!  🥳\n\n@TigresOficial está de ...    record_mexico
# 14  Ritmu! Ritmu!!!🤠🐎🌵El maltés Aidan será el alma...     eurospaincom
# 15  En la recta final de nuestro Carnaval quiero d...    CosseCarolina
# 16  🗳️Estaremos en Colombia🇨🇴 para monitorear las ...   uniglobalunion
# 17  Comenzamos la novena al Santo Cura Brochero de...        aciprensa
# 18  Cuando la fiesta es en tu casa y ya te quieres...   MarioAguilarMG
# 19  🤝 Vivamos este partido como una fiesta. #Fútbo...     AlianzaFC_sv
# 20  Que el fútbol siempre sea una fiesta. 🥁🎺🏳🏁 #Fú...     AlianzaFC_sv
# 21  “Que no le falte pueblo a nuestro presidente. ...          proceso
# 22  #Queretaro La violencia nunca es el camino. El...      EVerastegui
# 23  Tremendo acto con caravana del NO!\nUn fiesta ...   Dip_ConradoRod
# 24  Esto fue sólo parte de la fiesta. La caballada...         casiain1
# 25  El futbol TIENE/DEBE ser una fiesta familiar d...           lajosa
# 26  #Cuba🇨🇺 felicita al pueblo y gobierno de la Re...       CubaMINREX
# 27  El presidente @alferdez está dando un discurso...       WolffWaldo
# 28  "Después de ganar el US Open, no tenía dónde f...     VarskySports
# 29  Un estadio de fútbol es para muchos un santuar...      pavelpardo8
# 30  Hombre muere tras ser baleado en su cabeza: ha...           biobio
# 31  La argolla del poder en Napo también organizó ...   VillaFernando_
# 32  CONFIRMADO: UNO SE MUEVE AL RITMO DE LA HINCHA...          SC_ESPN
# 33  Extraordinaria Fiesta de la #Vendimia2022 🍇🇦🇷....        GugaLusto
# 34  Miren lo que fue parte de la fiesta de Uruguay...         casiain1
# 35  🥳 Y comenzamos el domingo con alegría, abrazos...       DvoTachira
# 36  ¡Llegó el mejor mes con las promos más reVelde...     viajaVolaris
# 37  🥳🎶 #CamilaCabello celebró su cumpleaños a lo g...    FMvidaRosario
# 38  Dice el de Petroperú que Jamas ha visto a Kare...      esquinabaja
# 39  En Bogotá estamos de fiesta!! Es el momento de...      DavidRacero
# 40  Lleno total en Bogotá. ⭐⭐⭐⭐⭐⭐⭐\n\n@pactocol \n...   PizarroMariaJo
# 41  ¡LA FIESTA QUE HACEMOS SIEMPRE! https://t.co/G...          Newells
# 42  ¡La vida es una fiesta! 🎉 busca tu mejor disfr...        VTVcanal8
# 43  Polémica: Mauricio Isla se perdió partido de F...      Cooperativa
# 44  Carlos Antonio Linares es un degenerado sexual...            PNCSV
# 45  Este fin de semana, acompañamos al Carnaval de...  AlvaroDelgadoUy
# 46  🥁🎉¡Hoy llegan los Carnavales a Almirante Brown...    CascallaresPJ
# 47  TODOS JUNTOS SOMOS PARTE DE ESTA FIESTA, SE VI...          _LBDTW_
# 48  ¡Ya está Trueno en el Carnaval de Pilar! ⚡🤟🏻\n...  FedericoAchaval
# 49  Se viene el #Belgrano360 un recibimiento histó...          _LBDTW_
# 50  🤍💙 ¡Todos a Butarque y que ningún abonado se q...        CDLeganes
# 51  Hoy en Sevilla. Hemos venido los de @vox_malag...  rubenmansolivar
# 52  La Fiesta del Cambio #ComienzaElCambio #ElPact...      RoyBarreras
#
#         fecha  #retweets                       menciones
# 0  2022-03-08     1947.0                  [@razón, @abc]
# 1  2022-03-08      969.0                              []
# 2  2022-03-06      400.0                              []
# 3  2022-03-06        NaN                   [@fincamarta]
# 4  2022-03-07      191.0                              []
# 5  2022-03-07       76.0                  [@rr, @locura]
# 6  2022-03-07       65.0   [@BlandonJose, @panamenistas]
# 7  2022-03-07        NaN                     [@jlespert]
# 8  2022-03-06     1348.0                              []
# 9  2022-03-07       47.0                              []
# 10 2022-03-06      116.0                              []
# 11 2022-03-08        NaN                              []
# 12 2022-03-07       50.0                              []
# 13 2022-03-07       46.0                [@TigresOficial]
# 14 2022-03-06       45.0                  [@pepe, @juan]
# 15 2022-03-07        NaN                              []
# 16 2022-03-07        NaN                        [@s, @s]
# 17 2022-03-07       28.0                              []
# 18 2022-03-06       48.0                              []
# 19 2022-03-06       91.0                              []
# 20 2022-03-07       19.0                              []
# 21 2022-03-06       17.0                              []
# 22 2022-03-06      105.0                              []
# 23 2022-03-06       49.0                              []
# 24 2022-03-06        NaN                              []
# 25 2022-03-06      140.0                              []
# 26 2022-03-06       91.0                              []
# 27 2022-03-01     2691.0                     [@alferdez]
# 28 2022-03-02      861.0                              []
# 29 2022-03-06      386.0                              []
# 30 2022-03-06       41.0                              []
# 31 2022-03-06      150.0                              []
# 32 2022-03-03      647.0                 [@EdelpOficial]
# 33 2022-03-06       33.0                              []
# 34 2022-03-06        NaN                              []
# 35 2022-03-06       34.0                  [@RonaldoCh10]
# 36 2022-03-01      273.0                              []
# 37 2022-03-06       46.0                              []
# 38 2022-03-02      309.0                              []
# 39 2022-03-04      336.0       [@PactoCol, @BogotaPacta]
# 40 2022-03-05      288.0                     [@pactocol]
# 41 2022-02-28      380.0                              []
# 42 2022-02-28      195.0                              []
# 43 2022-02-28      106.0                              []
# 44 2022-02-28      103.0                              []
# 45 2022-02-28       35.0              [@jose_yurramendi]
# 46 2022-02-28       42.0                            [@s]
# 47 2022-02-28       42.0                              []
# 48 2022-02-28       23.0                              []
# 49 2022-02-28       34.0                              []
# 50 2022-02-28       18.0                              []
# 51 2022-02-28       26.0  [@vox_malaga, @Macarena_Olona]
# 52 2022-02-28       29.0                              []

# %% [markdown]
# __EJ 12.__ Añadir una columna con los hastags que haya en el texto del tweet.

# %%
# sol:

# %% [markdown]
# ## Referencias
#
# * Construcción de Expresiones Regulares para la búsqueda de patrones https://docs.python.org/3/howto/regex.html#regex-howto
