# %% [markdown]
# # Ejercicios

# %% [markdown]
# Los enlaces que te encuentres en esta página, solo funcionan desde el formato html, no desde el notebook una vez descargado.

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# El fichero [tips.txt](./datos/tips.txt) recoge los datos asociados a las reservas de un restaurante durante un periodo de tiempo. Muestra los datos de 6 variables numéricas:
#
# * El precio de la factura,
# * La propina asociada a la factura,
# * El sexo de la persona que hizo la reserva (1=Hombre, 2=Mujer),
# * Si es una reserva para fumadores o no (0 = No Fumadores, 1 = Fumadores),
# * El día de la semana (1 = Lunes, ... , 7 = Domingo),
# * El número de comensales.
#
# Haz una pequeña exploración de los datos del fichero. Observa que el separador de datos es el símbolo coma(,).
#
# Realiza la carga de los datos con la función __read_csv__ del módulo __Pandas__. El dataFrame devuelto se llamará __tips__.

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 10.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
#      -------------------------------------- 163.0/163.0 kB 2.4 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.2-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 8.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.4/55.4 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\sergi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sergi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.4.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 10.5 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      -------------------------------------- 98.3/98.3 kB 808.2 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sergi\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sergi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.2 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.4.0 pyparsing-3.0.9
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sergi\appdata\local\programs\python\python311\lib\site-packages (22.3.1)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 10.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# Successfully installed pip-23.0.1

# %%
# Sol:
# Imports necesarios
import pandas as pd                         # importación de numpy

# Para dibujar:
import matplotlib.pyplot as plt
# %matplotlib inline

tips = pd.read_csv("./datos/tips.txt")
tips
# Out:
#      total_bill   tip  sex  smoker  day  table_size
# 0         16.99  1.01    2       0    7           2
# 1         10.34  1.66    1       0    7           3
# 2         21.01  3.50    1       0    7           3
# 3         23.68  3.31    1       0    7           2
# 4         24.59  3.61    2       0    7           4
# ..          ...   ...  ...     ...  ...         ...
# 239       29.03  5.92    1       0    6           3
# 240       27.18  2.00    2       1    6           2
# 241       22.67  2.00    1       1    6           2
# 242       17.82  1.75    1       0    6           2
# 243       18.78  3.00    2       0    4           2
#
# [244 rows x 6 columns]

# %% [markdown]
# __a)__ ¿Cuántas filas hemos cargado?

# %%
# Sol:

tips.shape
# Out:
# (244, 6)

# %% [markdown]
# __b)__ Muestra las 10 primeras filas

# %%
# Sol:

tips.head(10)
# Out:
#    total_bill   tip  sex  smoker  day  table_size
# 0       16.99  1.01    2       0    7           2
# 1       10.34  1.66    1       0    7           3
# 2       21.01  3.50    1       0    7           3
# 3       23.68  3.31    1       0    7           2
# 4       24.59  3.61    2       0    7           4
# 5       25.29  4.71    1       0    7           4
# 6        8.77  2.00    1       0    7           2
# 7       26.88  3.12    1       0    7           4
# 8       15.04  1.96    1       0    7           2
# 9       14.78  3.23    1       0    7           2

# %%
tips.tail(10)
# Out:
#      total_bill   tip  sex  smoker  day  table_size
# 234       15.53  3.00    1       1    6           2
# 235       10.07  1.25    1       0    6           2
# 236       12.60  1.00    1       1    6           2
# 237       32.83  1.17    1       1    6           2
# 238       35.83  4.67    2       0    6           3
# 239       29.03  5.92    1       0    6           3
# 240       27.18  2.00    2       1    6           2
# 241       22.67  2.00    1       1    6           2
# 242       17.82  1.75    1       0    6           2
# 243       18.78  3.00    2       0    4           2

# %% [markdown]
# __c)__ Calcula el importe máximo y mínimo de las facturas.

# %%
# Sol:

tips['total_bill'].max()
# Out:
# 50.81

# %%
tips['total_bill'].min()
# Out:
# 3.07

# %% [markdown]
# __d)__ Representa gráficamente mediante un diagrama de caja los datos correspondientes al importe de la factura. Puedes utilizar la función __boxplot__.

# %%
# Sol:
fig, (g)= plt.subplots(1, figsize=(5,3))
tips.total_bill.plot(kind = 'box', ax =g)
# Opción: Pinta una cuadrícula en la gráfica
g.grid(True) 


g.set_title('BoxPlot')
g.set_xticklabels([ 'Propina']);

# %% [markdown]
# __e)__  Representa gráficamente la relación entre el importe de la factura y la propina. Genera un diagrama de dispersión utilizando la función __scatter__.

# %%
# Sol:
# Sol  relación entre el  importe factura y la propina.
fig, ax1 = plt.subplots(nrows = 1, figsize=(7, 3))   

importe = tips['total_bill']
propina = tips.tip

ax1.scatter(importe, propina, marker = 'o')   
ax1.set_title('Diagrama de dispersion')
ax1.set_xlabel('Importe')
ax1.set_ylabel('Propina');

# %% [markdown]
# __f)__ Calcula la media del número de comensales.

# %%
# Sol:

tips['table_size'].mean()
# Out:
# 2.569672131147541

# %%
tips['table_size'].min()
# Out:
# 1

# %% [markdown]
# __g)__ Calcula el coeficiente de correlación entre el importe y la propina.

# %%
# Sol:

tips.loc[:,['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# __h)__ Importe medio de factura de las mujeres fumadoras.

# %%
# Sol:
"""
0 = No Fumador
1 = Fumador

2 = 'Mujeres'
1 = 'Hombres'
"""
filtro_mujer = tips['sex']==2
filtro_smoker = tips['smoker']==1

mujeres_fumadoras = tips[filtro_mujer & filtro_smoker]
mujeres_fumadoras
# Out:
#      total_bill   tip  sex  smoker  day  table_size
# 67         3.07  1.00    2       1    6           1
# 72        26.86  3.14    2       1    6           2
# 73        25.28  5.00    2       1    6           2
# 92         5.75  1.00    2       1    5           2
# 93        16.32  4.30    2       1    5           2
# 100       11.35  2.50    2       1    5           2
# 101       15.38  3.00    2       1    5           2
# 102       44.30  2.50    2       1    6           3
# 103       22.42  3.48    2       1    6           2
# 109       14.31  4.00    2       1    6           2
# 164       17.51  3.00    2       1    7           2
# 168       10.59  1.61    2       1    6           2
# 169       10.63  2.00    2       1    6           2
# 178        9.60  4.00    2       1    7           2
# 186       20.90  3.50    2       1    7           3
# 188       18.15  3.50    2       1    7           3
# 191       19.81  4.19    2       1    4           2
# 197       43.11  5.00    2       1    4           4
# 198       13.00  2.00    2       1    4           2
# 201       12.74  2.01    2       1    4           2
# 202       13.00  2.00    2       1    4           2
# 203       16.40  2.50    2       1    4           2
# 205       16.47  3.23    2       1    4           3
# 209       12.76  2.23    2       1    6           2
# 213       13.27  2.50    2       1    6           2
# 214       28.17  6.50    2       1    6           3
# 215       12.90  1.10    2       1    6           2
# 219       30.14  3.09    2       1    6           4
# 221       13.42  3.48    2       1    5           2
# 225       16.27  2.50    2       1    5           2
# 226       10.09  2.00    2       1    5           2
# 229       22.12  2.88    2       1    6           2
# 240       27.18  2.00    2       1    6           2

# %%
mujeres_fumadoras['total_bill'].mean()
# Out:
# 17.977878787878787

# %% [markdown]
# __i)__ Calcula la mediana del importe de la factura de los hombres.

# %% [markdown]
# __j)__ Calcula el importe total pagado (importe factura + propina). Guarda el resultado en una nueva columna.

# %%
# Sol:

tips['importe_total'] = tips['total_bill'] + tips['tip']

# %%
tips
# Out:
#      total_bill   tip  sex  smoker  day  table_size  importe_total
# 0         16.99  1.01    2       0    7           2          18.00
# 1         10.34  1.66    1       0    7           3          12.00
# 2         21.01  3.50    1       0    7           3          24.51
# 3         23.68  3.31    1       0    7           2          26.99
# 4         24.59  3.61    2       0    7           4          28.20
# ..          ...   ...  ...     ...  ...         ...            ...
# 239       29.03  5.92    1       0    6           3          34.95
# 240       27.18  2.00    2       1    6           2          29.18
# 241       22.67  2.00    1       1    6           2          24.67
# 242       17.82  1.75    1       0    6           2          19.57
# 243       18.78  3.00    2       0    4           2          21.78
#
# [244 rows x 7 columns]

# %% [markdown]
# __k)__ Crea una nueva columna llamada `Fumandor_cat ` que tenfa valor `F` si se trata de un cliente fumador y `NF` si se trata de un cliente no fumador.

# %%
# Sol:

tips['Fumador_cat'] = tips['smoker'].map(lambda valor : 'F' if valor==1 else 'NF')

# %%
tips
# Out:
#      total_bill   tip  sex  smoker  day  table_size  importe_total Fumador_cat
# 0         16.99  1.01    2       0    7           2          18.00          NF
# 1         10.34  1.66    1       0    7           3          12.00          NF
# 2         21.01  3.50    1       0    7           3          24.51          NF
# 3         23.68  3.31    1       0    7           2          26.99          NF
# 4         24.59  3.61    2       0    7           4          28.20          NF
# ..          ...   ...  ...     ...  ...         ...            ...         ...
# 239       29.03  5.92    1       0    6           3          34.95          NF
# 240       27.18  2.00    2       1    6           2          29.18           F
# 241       22.67  2.00    1       1    6           2          24.67           F
# 242       17.82  1.75    1       0    6           2          19.57          NF
# 243       18.78  3.00    2       0    4           2          21.78          NF
#
# [244 rows x 8 columns]

# %% [markdown]
# __l)__ Cuántos clientes fumadores hay en el dataframe?

# %%
# Sol:

len(tips[filtro_smoker])
# Out:
# 93

# %% [markdown]
# ---------------------
